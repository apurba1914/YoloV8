# %%
from ultralytics import YOLO

# %%
# Load a YOLOv8 model (pretrained or new)
model = YOLO('yolov8n.pt')  # Replace with 'yolov8s.pt', 'yolov8m.pt', etc., for different sizes
# Out:
# ...
# 100%|██████████████████████████████████████████████████████████████████████████████| 6.25M/6.25M [00:24<00:00, 270kB/s]

# %%
# Train the model
model.train(data='D:/YOLO/SeedlingSegmentation.4stages/data.yaml', epochs=50, imgsz=640, batch=16)
# Out:
# New https://pypi.org/project/ultralytics/8.3.33 available  Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.2.98  Python-3.10.1 torch-2.4.1+cpu CPU (AMD Ryzen 7 4800H with Radeon Graphics)
# ...

# %%
metrics = model.val()  # Runs validation on the validation set
# Out:
# Ultralytics YOLOv8.2.98  Python-3.10.1 torch-2.4.1+cpu CPU (AMD Ryzen 7 4800H with Radeon Graphics)
# Model summary (fused): 168 layers, 3,006,428 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning D:\YOLO\SeedlingSegmentation.4stages\valid\labels.cache... 106 images, 0 backgrounds, 0 corrupt: 100%|███
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 7/7 [00:09<0
#                    all        106       1564      0.737      0.663      0.719      0.378
#            seedling_s1         27        332      0.669      0.666      0.662      0.259
#            seedling_s2         37        489      0.753      0.712      0.782       0.44
#            seedling_s3          8        212      0.736      0.382      0.519      0.175
#            seedling_s4         34        531      0.789      0.891      0.912      0.637
# Speed: 1.6ms preprocess, 62.2ms inference, 0.0ms loss, 0.4ms postprocess per image
# ...

# %%
results = model.predict(source="D:/YOLO/SeedlingSegmentation.4stages/valid/images/DJI_0243_JPG.rf.7b831dde5e23dd8e2efe4a7b2a27f564.jpg", conf=0.5)
# Out:
# image 1/1 D:\YOLO\SeedlingSegmentation.4stages\valid\images\DJI_0243_JPG.rf.7b831dde5e23dd8e2efe4a7b2a27f564.jpg: 640x640 4 seedling_s3s, 311.7ms
# Speed: 2.0ms preprocess, 311.7ms inference, 35.0ms postprocess per image at shape (1, 3, 640, 640)

# %%
from ultralytics import YOLO
import cv2
from matplotlib import pyplot as plt

# Load your trained YOLOv8 model
model = YOLO("C:/Users/APURBA ROY/runs/detect/train3/weights/best.pt")

# Path to the image you want to predict on
image_path = 'D:/YOLO/SeedlingSegmentation.4stages/valid/images/DJI_0243_JPG.rf.7b831dde5e23dd8e2efe4a7b2a27f564.jpg'

# Perform prediction
results = model.predict(source=image_path, save=False, conf=0.5)

# Extract annotated image
annotated_image = results[0].plot()  # Draw predictions on the image

# Display the image using matplotlib
plt.figure(figsize=(10, 10))
plt.imshow(cv2.cvtColor(annotated_image, cv2.COLOR_BGR2RGB))  # Convert BGR to RGB for correct colors
plt.axis('off')
plt.show()
# Out:
# image 1/1 D:\YOLO\SeedlingSegmentation.4stages\valid\images\DJI_0243_JPG.rf.7b831dde5e23dd8e2efe4a7b2a27f564.jpg: 640x640 4 seedling_s3s, 56.0ms
# Speed: 3.0ms preprocess, 56.0ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 640)

# %%
model.export(format='torchscript')  # Supported formats: 'onnx', 'torchscript', 'coreml', etc.
# Out:
# Ultralytics YOLOv8.2.98  Python-3.10.1 torch-2.4.1+cpu CPU (AMD Ryzen 7 4800H with Radeon Graphics)
#
# PyTorch: starting from 'C:\Users\APURBA ROY\runs\detect\train3\weights\best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 8, 8400) (6.0 MB)
#
# TorchScript: starting export with torch 2.4.1+cpu...
# TorchScript: export success  3.1s, saved as 'C:\Users\APURBA ROY\runs\detect\train3\weights\best.torchscript' (11.9 MB)
#
# Export complete (3.3s)
# Results saved to C:\Users\APURBA ROY\runs\detect\train3\weights
# Predict:         yolo predict task=detect model=C:\Users\APURBA ROY\runs\detect\train3\weights\best.torchscript imgsz=640
# Validate:        yolo val task=detect model=C:\Users\APURBA ROY\runs\detect\train3\weights\best.torchscript imgsz=640 data=D:/YOLO/SeedlingSegmentation.4stages/data.yaml
# Visualize:       https://netron.app
# 'C:\\Users\\APURBA ROY\\runs\\detect\\train3\\weights\\best.torchscript'
